# %%
from src import *
form = {
    Generic('{}.json', DataTypes.IMAGE_SET_NAME): JSONFile({
        'images': GenericList([{
            'id': DataTypes.IMAGE_ID,
            'file_name': Generic('{}.jpg', DataTypes.IMAGE_NAME)
        }]),
        'categories': GenericList([{
            'id': DataTypes.BBOX_CLASS_ID,
            'name': DataTypes.BBOX_CLASS_NAME
        }]),
        'annotations': GenericList([{
            'image_id': DataTypes.IMAGE_ID,
            'category_id': DataTypes.BBOX_CLASS_ID,
            'bbox': GenericList([
                DataTypes.X1, DataTypes.Y1, DataTypes.X2, DataTypes.Y2
            ])
        }])
    }),
    'images': {
        Generic('{}.jpg', DataTypes.IMAGE_NAME): Image()
    }
}
cvdata = CVData('/Users/atong/Documents/Datasets/Avo', form)
cvdata.cleanup()
# Out:
# [CVData] Cleaning up data...
# [CVData] Converting IMAGE_SET names to IMAGE_SET_ID
# [CVData] Done!

# %%
from src import *
alias = Alias([
    Generic("{}", DataTypes.IMAGE_NAME),
    Generic("{}_{}", DataTypes.CLASS_NAME, DataTypes.GENERIC)
])
root = '/Users/atong/Documents/Datasets/OxfordPets'
form = {
    Static("annotations"): {
        Generic("{}.txt", DataTypes.IMAGE_SET_NAME, ignore='list'): TXTFile(
            Generic(
                "{} {} {} {}", alias, DataTypes.CLASS_ID, DataTypes.GENERIC, DataTypes.GENERIC
            ),
            ignore_type = '#'
        ),
        "trimaps": {
            Generic("{}.png", DataTypes.IMAGE_NAME): SegmentationImage()
        }
    },
    Static("images"): {
        Generic("{}.jpg", alias): Image()
    },
    Static("class.txt"): TXTFile(
        Generic("{} {}", DataTypes.CLASS_NAME, DataTypes.CLASS_ID)
    )
}
cvdata = CVData(root, form)
cvdata.cleanup()
# Out:
# [CVData] Cleaning up data...
# [CVData] Converting IMAGE_SET names to IMAGE_SET_ID
# [CVData] Done!

# %%
cvdata.available_modes
# Out:
# ['segmentation']

# %%
dataloader = cvdata.get_dataloader('segmentation', 'result')
# Out:
# Removed 1 NaN entries.

# %%
dataset = cvdata.get_dataset('segmentation', 'result')
# Out:
# Removed 1 NaN entries.

# %%
dataset[0][1]
# Out:
# tensor([[3, 3, 3,  ..., 3, 3, 3],
#         [3, 3, 3,  ..., 3, 3, 3],
#         [3, 3, 3,  ..., 3, 3, 3],
#         ...,
#         [3, 3, 3,  ..., 3, 3, 3],
#         [3, 3, 3,  ..., 3, 3, 3],
#         [3, 3, 3,  ..., 3, 3, 3]], dtype=torch.int32)

# %%
from src import *
form = {
    Generic('{}.json', DataTypes.IMAGE_SET_NAME): JSONFile({
        'images': GenericList([{
            'id': DataTypes.IMAGE_ID,
            'file_name': Generic('{}.jpg', DataTypes.IMAGE_NAME)
        }]),
        'categories': GenericList([{
            'id': DataTypes.SEG_CLASS_ID,
            'name': DataTypes.SEG_CLASS_NAME
        }]),
        'annotations': GenericList([{
            'image_id': DataTypes.IMAGE_ID,
            'category_id': DataTypes.SEG_CLASS_ID,
            'segmentation': GenericList(SegmentationObject([
                DataTypes.X, DataTypes.Y
            ]))
        }])
    }),
    'images': {
        Generic('{}.jpg', DataTypes.IMAGE_NAME): Image()
    }
}
cvdata = CVData('/Users/atong/Documents/Datasets/AvoMasks', form)
cvdata.cleanup()
# Out:
# [CVData] Cleaning up data...
# [CVData] Converting IMAGE_SET names to IMAGE_SET_ID
# [CVData] Done!

# %%
cvdata.dataframe
# Out:
#     IMAGE_ID              IMAGE_NAME              SEG_CLASS_ID  \
# 0          3  PXL_20220919_184826135              [2, 1, 1, 1]
# 1         17  PXL_20220919_184804102                    [2, 1]
# 2         11  PXL_20220919_184951515                    [2, 1]
# 3          7  PXL_20220919_184929738                    [2, 1]
# 4          5  PXL_20220919_184910583                    [2, 1]
# 5          0  PXL_20220919_184805662                 [2, 1, 1]
# 6         10  PXL_20220919_184946974                    [2, 1]
# 7         14  PXL_20220919_184757665                    [2, 1]
# 8         15  PXL_20220919_184800783                    [2, 1]
# 9          2  PXL_20220919_184809263              [2, 1, 1, 1]
# 10         8  PXL_20220919_184932065                 [2, 1, 1]
# 11         6  PXL_20220919_184912282                 [2, 1, 1]
# 12         9  PXL_20220919_184935939                    [2, 1]
# 13        13  PXL_20220919_184739642  [2, 1, 2, 1, 2, 1, 2, 1]
# 14         4  PXL_20220919_184900539                 [2, 1, 1]
# 15        12  PXL_20220919_184737755     [2, 2, 2, 1, 1, 1, 1]
# 16         1  PXL_20220919_184807037              [2, 1, 1, 1]
# 17        16  PXL_20220919_184802787                    [2, 1]
#
#                                               POLYGON    IMAGE_SET_NAME  \
# 0   [[(28.57142857142857, 950.7142857142858), (71....          [result]
# 1   [[(1381.6521739130435, 3104.3478260869565), (1...  [result, images]
# 2   [[(1541.0, 1471.0), (1555.0, 1500.0), (1589.0,...  [result, images]
# 3   [[(267.81818181818187, 30.90909090909096), (30...  [result, images]
# 4   [[(12.0, 128.0), (12.0, 1560.0), (56.0, 1540.0...  [result, images]
# 5   [[(542.8571428571427, 1682.1428571428569), (57...  [result, images]
# 6   [[(1452.2162162162163, 308.91891891891896), (1...  [result, images]
# 7   [[(1981.6521739130437, 3513.913043478261), (20...  [result, images]
# 8   [[(1431.0000000000002, 832.4999999999999), (15...  [result, images]
# 9   [[(1338.7096774193549, 3377.0967741935483), (1...  [result, images]
# 10  [[(1043.3333333333335, 3196.6666666666665), (1...  [result, images]
# 11  [[(525.8064516129032, 1183.5483870967741), (52...  [result, images]
# 12  [[(1592.25, 731.25), (1636.0, 747.916666666666...  [result, images]
# 13  [[(2777.777777777777, 1767.7777777777778), (27...  [result, images]
# 14  [[(1457.142857142857, 2814.285714285714), (151...  [result, images]
# 15  [[(1594.0170940170942, 2679.3162393162393), (1...  [result, images]
# 16  [[(1125.8064516129032, 883.5483870967741), (11...  [result, images]
# 17  [[(1822.8070175438597, 596.1403508771932), (17...  [result, images]
#
#                                         ABSOLUTE_FILE IMAGE_SET_ID
# 0                                                 NaN          [0]
# 1   /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 2   /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 3   /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 4   /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 5   /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 6   /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 7   /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 8   /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 9   /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 10  /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 11  /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 12  /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 13  /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 14  /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 15  /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 16  /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]
# 17  /Users/atong/Documents/Datasets/AvoMasks/image...       [0, 1]

# %%
import matplotlib.pyplot as plt
