# %%
from src import *
form = {
    Generic('{}.json', DataTypes.IMAGE_SET_NAME): JSONFile({
        'images': GenericList([{
            'id': DataTypes.IMAGE_ID,
            'file_name': Generic('{}.jpg', DataTypes.IMAGE_NAME)
        }]),
        'categories': GenericList([{
            'id': DataTypes.BBOX_CLASS_ID,
            'name': DataTypes.BBOX_CLASS_NAME
        }]),
        'annotations': GenericList([{
            'image_id': DataTypes.IMAGE_ID,
            'category_id': DataTypes.BBOX_CLASS_ID,
            'bbox': GenericList([
                DataTypes.X1, DataTypes.Y1, DataTypes.X2, DataTypes.Y2
            ])
        }])
    }),
    'images': {
        Generic('{}.jpg', DataTypes.IMAGE_NAME): Image()
    }
}
cvdata = CVData('/Users/atong/Documents/Datasets/Avo', form)
cvdata.cleanup()
# Out:
# [CVData] Cleaning up data...
# [CVData] Converting IMAGE_SET names to IMAGE_SET_ID
# [CVData] Done!

# %%
from src import *
alias = Alias([
    Generic("{}", DataTypes.IMAGE_NAME),
    Generic("{}_{}", DataTypes.CLASS_NAME, DataTypes.GENERIC)
])
root = '/Users/atong/Documents/Datasets/OxfordPets'
form = {
    Static("annotations"): {
        Generic("{}.txt", DataTypes.IMAGE_SET_NAME, ignore='list'): TXTFile(
            Generic(
                "{} {} {} {}", alias, DataTypes.CLASS_ID, DataTypes.GENERIC, DataTypes.GENERIC
            ),
            ignore_type = '#'
        )
    },
    Static("images"): {
        Generic("{}.jpg", alias): Image()
    },
    Static("class.txt"): TXTFile(
        Generic("{} {}", DataTypes.CLASS_NAME, DataTypes.CLASS_ID)
    )
}
cvdata = CVData(root, form)
cvdata.cleanup()
# Out:
# [CVData] Cleaning up data...
# [CVData] Converting IMAGE_SET names to IMAGE_SET_ID
# [CVData] Done!

# %%
dataloader = cvdata.get_dataloader('detection', 'test')
# Out:
# Removed 0 NaN entries.

# %%
dataset = cvdata.get_dataset('detection', 'temp')
# Out:
# Removed 0 NaN entries.

# %%
cvdata.image_set_to_idx
# Out:
# {'default': 0, 'test': 1, 'temp': 2, 'val': 3, 'train': 4, 'temp2': 5}

# %%
cvdata.image_set_to_idx
# Out:
# {'default': 0, 'test': 1, 'temp': 2, 'val': 3, 'train': 4, 'temp2': 5}

# %%
cvdata.available_modes
# Out:
# ['detection']

# %%
a = cvdata.dataframe.loc[cvdata.dataframe['CLASS_NAME'] == 'keeshond']['CLASS_ID']

# %%
cvdata.dataframe
# Out:
#                                    IMAGE_NAME  \
# 0    picam2-wideangle-RGB2023-Apr-15-17-26-50
# 1    picam2-wideangle-RGB2023-Apr-15-17-26-44
# 2    picam2-wideangle-RGB2023-Apr-15-17-32-31
# 3    picam2-wideangle-RGB2023-Apr-15-17-28-41
# 4    picam2-wideangle-RGB2023-Apr-15-17-32-19
# ..                                        ...
# 540  picam2-wideangle-RGB2023-Apr-15-17-25-29
# 541  picam2-wideangle-RGB2023-Apr-15-17-28-25
# 542  picam2-wideangle-RGB2023-Apr-15-17-25-15
# 543                    PXL_20220919_184946974
# 544  picam2-wideangle-RGB2023-Apr-15-17-28-31
#
#                                          ABSOLUTE_FILE  IMAGE_ID  \
# 0    /Users/atong/Documents/Datasets/Avo/images/pic...       542
# 1    /Users/atong/Documents/Datasets/Avo/images/pic...       524
# 2    /Users/atong/Documents/Datasets/Avo/images/pic...      1235
# 3    /Users/atong/Documents/Datasets/Avo/images/pic...       766
# 4    /Users/atong/Documents/Datasets/Avo/images/pic...      1203
# ..                                                 ...       ...
# 540  /Users/atong/Documents/Datasets/Avo/images/pic...       336
# 541  /Users/atong/Documents/Datasets/Avo/images/pic...       730
# 542  /Users/atong/Documents/Datasets/Avo/images/pic...       318
# 543  /Users/atong/Documents/Datasets/Avo/images/PXL...        49
# 544  /Users/atong/Documents/Datasets/Avo/images/pic...       748
#
#                                          BBOX_CLASS_ID  \
# 0                          [2, 2, 2, 2, 2, 1, 0, 1, 0]
# 1    [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# 2                       [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# 3                          [3, 3, 3, 3, 3, 3, 0, 3, 3]
# 4              [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 0]
# ..                                                 ...
# 540               [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# 541  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 0, ...
# 542                     [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# 543  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# 544            [3, 3, 3, 3, 3, 3, 3, 3, 0, 0, 0, 0, 0]
#
#                                                     X1  \
# 0    [118.00475059382421, 297.5771971496437, 293.72...
# 1    [421.31207872940183, 356.80115552130815, 452.3...
# 2    [751.49847608128, 715.2612873334667, 593.17229...
# 3    [99.77677934577187, 66.02875103764316, 29.3461...
# 4    [801.5484655639899, 726.2448542721755, 648.321...
# ..                                                 ...
# 540  [102.42964930573766, 18.444656983603977, 211.6...
# 541  [810.7896676184208, 882.6437481421535, 953.947...
# 542  [1175.5551303401155, 1100.9649227520938, 678.3...
# 543  [592.3266218105514, 825.8132665879851, 773.508...
# 544  [742.1398416659126, 816.3471971066907, 857.359...
#
#                                                     Y1  \
# 0    [336.0570071258907, 291.16389548693587, 339.90...
# 1    [763.0007222008178, 641.1467561410855, 664.243...
# 2    [187.2189925399091, 346.59264230158163, 448.30...
# 3    [89.50564029547184, 14.673055786142926, 343.34...
# 4    [276.9863267516299, 268.4737446055987, 251.448...
# ..                                                 ...
# 540  [757.7105207348884, 837.5845082154908, 864.436...
# 541  [431.3627454890168, 306.2449167642925, 282.028...
# 542  [871.2959607096009, 585.1641259087864, 94.8436...
# 543  [1774.1032223367683, 1257.8376498492053, 1324....
# 544  [386.6907775768535, 281.2296564195299, 183.580...
#
#                                                     X2  \
# 0    [44.89311163895486, 47.458432304038, 52.589073...
# 1    [39.025126385143096, 43.007282138729096, 28.67...
# 2    [66.6967660923426, 47.22585747330833, 53.03827...
# 3    [74.83258450932891, 61.626834301800244, 67.496...
# 4    [49.76586485372078, 45.8369807863218, 37.32439...
# ..                                                 ...
# 540  [72.22328491801977, 69.82620143792933, 64.7894...
# 541  [67.14534503408882, 70.6310323446008, 66.59497...
# 542  [70.43221201725657, 64.3919444491845, 69.39779...
# 543  [104.08659514578817, 142.0710373432618, 89.199...
# 544  [87.88426763110304, 58.589511754068866, 46.871...
#
#                                                     Y2 IMAGE_SET_NAME  \
# 0    [41.04513064133019, 32.066508313539174, 46.175...        [train]
# 1    [42.21085098801184, 38.22869523442576, 35.8394...         [test]
# 2    [57.33581646534718, 46.49930581987298, 46.4993...         [test]
# 3    [61.62683430180027, 44.019167358428774, 54.290...         [test]
# 4    [46.49179479755494, 41.90809671892278, 37.3243...          [val]
# ..                                                 ...            ...
# 540  [69.58833392036212, 75.09610343324482, 59.3903...        [train]
# 541  [60.54088486680189, 48.432707893442156, 63.904...        [train]
# 542  [63.950720113828346, 51.220864902760425, 49.34...        [train]
# 543  [92.26187381353057, 89.19979142144821, 89.1997...          [val]
# 544  [85.93128390596745, 76.16636528028934, 48.8245...        [train]
#
#                                                   XMIN  \
# 0    [44.89311163895486, 47.458432304038, 52.589073...
# 1    [39.025126385143096, 43.007282138729096, 28.67...
# 2    [66.6967660923426, 47.22585747330833, 53.03827...
# 3    [74.83258450932891, 61.626834301800244, 29.346...
# 4    [49.76586485372078, 45.8369807863218, 37.32439...
# ..                                                 ...
# 540  [72.22328491801977, 18.444656983603977, 64.789...
# 541  [67.14534503408882, 70.6310323446008, 66.59497...
# 542  [70.43221201725657, 64.3919444491845, 69.39779...
# 543  [104.08659514578817, 142.0710373432618, 89.199...
# 544  [87.88426763110304, 58.589511754068866, 46.871...
#
#                                                   YMIN  \
# 0    [41.04513064133019, 32.066508313539174, 46.175...
# 1    [42.21085098801184, 38.22869523442576, 35.8394...
# 2    [57.33581646534718, 46.49930581987298, 46.4993...
# 3    [61.62683430180027, 14.673055786142926, 54.290...
# 4    [46.49179479755494, 41.90809671892278, 37.3243...
# ..                                                 ...
# 540  [69.58833392036212, 75.09610343324482, 59.3903...
# 541  [60.54088486680189, 48.432707893442156, 63.904...
# 542  [63.950720113828346, 51.220864902760425, 49.34...
# 543  [92.26187381353057, 89.19979142144821, 89.1997...
# 544  [85.93128390596745, 76.16636528028934, 48.8245...
#
#                                                   XMAX  \
# 0    [118.00475059382421, 297.5771971496437, 293.72...
# 1    [421.31207872940183, 356.80115552130815, 452.3...
# 2    [751.49847608128, 715.2612873334667, 593.17229...
# 3    [99.77677934577187, 66.02875103764316, 67.4960...
# 4    [801.5484655639899, 726.2448542721755, 648.321...
# ..                                                 ...
# 540  [102.42964930573766, 69.82620143792933, 211.60...
# 541  [810.7896676184208, 882.6437481421535, 953.947...
# 542  [1175.5551303401155, 1100.9649227520938, 678.3...
# 543  [592.3266218105514, 825.8132665879851, 773.508...
# 544  [742.1398416659126, 816.3471971066907, 857.359...
#
#                                                   YMAX IMAGE_SET_ID
# 0    [336.0570071258907, 291.16389548693587, 339.90...          [4]
# 1    [763.0007222008178, 641.1467561410855, 664.243...          [1]
# 2    [187.2189925399091, 346.59264230158163, 448.30...          [1]
# 3    [89.50564029547184, 44.019167358428774, 343.34...          [1]
# 4    [276.9863267516299, 268.4737446055987, 251.448...          [3]
# ..                                                 ...          ...
# 540  [757.7105207348884, 837.5845082154908, 864.436...          [4]
# 541  [431.3627454890168, 306.2449167642925, 282.028...          [4]
# 542  [871.2959607096009, 585.1641259087864, 94.8436...          [4]
# 543  [1774.1032223367683, 1257.8376498492053, 1324....          [3]
# 544  [386.6907775768535, 281.2296564195299, 183.580...          [4]
#
# [545 rows x 14 columns]
