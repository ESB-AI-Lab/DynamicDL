# %%
from src import *
form = {
    Generic('{}.json', DataTypes.IMAGE_SET_NAME): JSONFile({
        'images': GenericList([{
            'id': DataTypes.IMAGE_ID,
            'file_name': Generic('{}.jpg', DataTypes.IMAGE_NAME)
        }]),
        'categories': Pairing(GenericList([{
            'id': DataTypes.BBOX_CLASS_ID,
            'name': DataTypes.BBOX_CLASS_NAME
        }]), DataTypes.BBOX_CLASS_ID, DataTypes.BBOX_CLASS_NAME),
        'annotations': GenericList([{
            'image_id': DataTypes.IMAGE_ID,
            'category_id': DataTypes.BBOX_CLASS_ID,
            'bbox': GenericList([
                DataTypes.X1, DataTypes.Y1, DataTypes.X2, DataTypes.Y2
            ])
        }])
    }),
    'images': {
        Generic('{}.jpg', DataTypes.IMAGE_NAME): Image()
    }
}
cvdata = CVData('/Users/atong/Documents/Datasets/Avo', form)
cvdata.cleanup()
# Out:
# [CVData] Cleaning up data...
# [CVData] Converting IMAGE_SET names to IMAGE_SET_ID
# [CVData] Done!

# %%
from src import *
alias = Alias([
    Generic("{}", DataTypes.IMAGE_NAME),
    Generic("{}_{}", DataTypes.CLASS_NAME, DataTypes.GENERIC)
])
root = '/Users/atong/Documents/Datasets/OxfordPets'
form = {
    Static("annotations"): {
        Generic("{}.txt", DataTypes.IMAGE_SET_NAME): TXTFile(
            GenericList(Generic(
                "{} {} {} {}", alias, DataTypes.CLASS_ID, DataTypes.GENERIC, DataTypes.GENERIC
            )),
            ignore_type = '#'
        ),
        "trimaps": {
            Generic("{}.png", DataTypes.IMAGE_NAME): SegmentationImage()
        }
    },
    Static("images"): {
        Generic("{}.jpg", alias): Image()
    },
    Static("class.txt"): TXTFile(
        Pairing(
            GenericList(Generic("{} {}", DataTypes.CLASS_NAME, DataTypes.CLASS_ID)), 
            DataTypes.CLASS_NAME, DataTypes.CLASS_ID
        )
    )
}
cvdata = CVData(root, form)
cvdata.cleanup()
# Out:
# [CVData] Cleaning up data...
# [CVData] Converting IMAGE_SET names to IMAGE_SET_ID
# [CVData] Done!

# %%
cvdata.available_modes
# Out:
# ['classification', 'segmentation']

# %%
from src import *
form = {
    Generic('{}.json', DataTypes.IMAGE_SET_NAME): JSONFile({
        'images': GenericList([{
            'id': DataTypes.IMAGE_ID,
            'file_name': Generic('{}.jpg', DataTypes.IMAGE_NAME)
        }]),
        'categories': Pairing(GenericList([{
            'id': DataTypes.SEG_CLASS_ID,
            'name': DataTypes.SEG_CLASS_NAME
        }]), DataTypes.SEG_CLASS_ID, DataTypes.SEG_CLASS_NAME),
        'annotations': GenericList([{
            'image_id': DataTypes.IMAGE_ID,
            'category_id': DataTypes.SEG_CLASS_ID,
            'segmentation': GenericList(SegmentationObject([
                DataTypes.X, DataTypes.Y
            ]))
        }])
    }),
    'images': {
        Generic('{}.jpg', DataTypes.IMAGE_NAME): Image()
    }
}
cvdata = CVData('/Users/atong/Documents/Datasets/AvoMasks', form)
cvdata.cleanup()
# Out:
# [CVData] Cleaning up data...
# [CVData] Converting IMAGE_SET names to IMAGE_SET_ID
# [CVData] Done!

# %%
cvdata.dataframe
# Out:
#                 IMAGE_NAME                                      ABSOLUTE_FILE  \
# 0   PXL_20220919_184946974  /Users/atong/Documents/Datasets/AvoMasks/image...
# 1   PXL_20220919_184951515  /Users/atong/Documents/Datasets/AvoMasks/image...
# 2   PXL_20220919_184809263  /Users/atong/Documents/Datasets/AvoMasks/image...
# 3   PXL_20220919_184826135                                                NaN
# 4   PXL_20220919_184912282  /Users/atong/Documents/Datasets/AvoMasks/image...
# 5   PXL_20220919_184935939  /Users/atong/Documents/Datasets/AvoMasks/image...
# 6   PXL_20220919_184910583  /Users/atong/Documents/Datasets/AvoMasks/image...
# 7   PXL_20220919_184805662  /Users/atong/Documents/Datasets/AvoMasks/image...
# 8   PXL_20220919_184804102  /Users/atong/Documents/Datasets/AvoMasks/image...
# 9   PXL_20220919_184739642  /Users/atong/Documents/Datasets/AvoMasks/image...
# 10  PXL_20220919_184757665  /Users/atong/Documents/Datasets/AvoMasks/image...
# 11  PXL_20220919_184800783  /Users/atong/Documents/Datasets/AvoMasks/image...
# 12  PXL_20220919_184932065  /Users/atong/Documents/Datasets/AvoMasks/image...
# 13  PXL_20220919_184802787  /Users/atong/Documents/Datasets/AvoMasks/image...
# 14  PXL_20220919_184807037  /Users/atong/Documents/Datasets/AvoMasks/image...
# 15  PXL_20220919_184737755  /Users/atong/Documents/Datasets/AvoMasks/image...
# 16  PXL_20220919_184900539  /Users/atong/Documents/Datasets/AvoMasks/image...
# 17  PXL_20220919_184929738  /Users/atong/Documents/Datasets/AvoMasks/image...
#
#     IMAGE_ID              SEG_CLASS_ID  \
# 0         10                    [2, 1]
# 1         11                    [2, 1]
# 2          2              [2, 1, 1, 1]
# 3          3              [2, 1, 1, 1]
# 4          6                 [2, 1, 1]
# 5          9                    [2, 1]
# 6          5                    [2, 1]
# 7          0                 [2, 1, 1]
# 8         17                    [2, 1]
# 9         13  [2, 1, 2, 1, 2, 1, 2, 1]
# 10        14                    [2, 1]
# 11        15                    [2, 1]
# 12         8                 [2, 1, 1]
# 13        16                    [2, 1]
# 14         1              [2, 1, 1, 1]
# 15        12     [2, 2, 2, 1, 1, 1, 1]
# 16         4                 [2, 1, 1]
# 17         7                    [2, 1]
#
#                                               POLYGON IMAGE_SET_NAME  \
# 0   [[(1452.2162162162163, 308.91891891891896), (1...       [result]
# 1   [[(1541.0, 1471.0), (1555.0, 1500.0), (1589.0,...       [result]
# 2   [[(1338.7096774193549, 3377.0967741935483), (1...       [result]
# 3   [[(28.57142857142857, 950.7142857142858), (71....       [result]
# 4   [[(525.8064516129032, 1183.5483870967741), (52...       [result]
# 5   [[(1592.25, 731.25), (1636.0, 747.916666666666...       [result]
# 6   [[(12.0, 128.0), (12.0, 1560.0), (56.0, 1540.0...       [result]
# 7   [[(542.8571428571427, 1682.1428571428569), (57...       [result]
# 8   [[(1381.6521739130435, 3104.3478260869565), (1...       [result]
# 9   [[(2777.777777777777, 1767.7777777777778), (27...       [result]
# 10  [[(1981.6521739130437, 3513.913043478261), (20...       [result]
# 11  [[(1431.0000000000002, 832.4999999999999), (15...       [result]
# 12  [[(1043.3333333333335, 3196.6666666666665), (1...       [result]
# 13  [[(1822.8070175438597, 596.1403508771932), (17...       [result]
# 14  [[(1125.8064516129032, 883.5483870967741), (11...       [result]
# 15  [[(1594.0170940170942, 2679.3162393162393), (1...       [result]
# 16  [[(1457.142857142857, 2814.285714285714), (151...       [result]
# 17  [[(267.81818181818187, 30.90909090909096), (30...       [result]
#
#                                        SEG_CLASS_NAME IMAGE_SET_ID
# 0                           [avocadotree, BaseBranch]          [0]
# 1                           [avocadotree, BaseBranch]          [0]
# 2   [avocadotree, BaseBranch, BaseBranch, BaseBranch]          [0]
# 3   [avocadotree, BaseBranch, BaseBranch, BaseBranch]          [0]
# 4               [avocadotree, BaseBranch, BaseBranch]          [0]
# 5                           [avocadotree, BaseBranch]          [0]
# 6                           [avocadotree, BaseBranch]          [0]
# 7               [avocadotree, BaseBranch, BaseBranch]          [0]
# 8                           [avocadotree, BaseBranch]          [0]
# 9   [avocadotree, BaseBranch, avocadotree, BaseBra...          [0]
# 10                          [avocadotree, BaseBranch]          [0]
# 11                          [avocadotree, BaseBranch]          [0]
# 12              [avocadotree, BaseBranch, BaseBranch]          [0]
# 13                          [avocadotree, BaseBranch]          [0]
# 14  [avocadotree, BaseBranch, BaseBranch, BaseBranch]          [0]
# 15  [avocadotree, avocadotree, avocadotree, BaseBr...          [0]
# 16              [avocadotree, BaseBranch, BaseBranch]          [0]
# 17                          [avocadotree, BaseBranch]          [0]

# %%
import matplotlib.pyplot as plt
